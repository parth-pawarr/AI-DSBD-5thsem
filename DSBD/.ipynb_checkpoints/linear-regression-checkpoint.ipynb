# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'Boston.csv'
try:
    df = pd.read_csv(file_path)
    print(f"\nDataset '{file_path}' loaded sucessfully intp a dataframe")

except FileNotFoundError:
    print(f"\nError: File '{file_path}' not found. Please check the file path.")
# Out:
# Dataset 'Boston.csv' loaded sucessfully intp a dataframe

# %%
df = housing.frame.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = housing.frame.copy()
#
# NameError: name 'housing' is not defined
